# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5] 
y = [1, 4, 9, 16, 25] 
z=[7,3,6,7,3]
plt.figure(figsize=(10,15))
plt.title('credit card')
plt.xlabel('no.of persons')
plt.ylabel('purchase list')
plt.plot(x,y)
plt.plot(y,z)
plt.scatter(x,y,z)
plt.bar(x,y)
plt.bar(y,z)
plt.show()
